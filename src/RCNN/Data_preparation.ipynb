# %%
''''
from google.colab import drive
drive.mount('/content/drive')
'''

# %%
'''
file = open("./train.txt","r+") 
url = []
for element in file:
  frcnn_f = element.split(' ')
  if len(frcnn_f[1:]) > 1:
    for i in range(len(frcnn_f[1:])):
      cr = frcnn_f[i+1].split(',')
      url_rcnn = f"{frcnn_f[0]},{cr[0]},{cr[1]},{cr[2]},{cr[3]},Plate"
      url.append(url_rcnn)
  else:
    cr = frcnn_f[1].split(',')
    url_rcnn = f"{frcnn_f[0]},{cr[0]},{cr[1]},{cr[2]},{cr[3]},Plate"
    url.append(url_rcnn)
'''

# %%
'''
url_file = open("./license_plate_train.txt", "w")
for element in url:
  url_file.write(element + "\n")  
url_file.close()
'''
